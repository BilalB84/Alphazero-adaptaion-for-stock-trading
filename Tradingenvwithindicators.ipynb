# %%
from alphazeroagent import AlphaZeroNetwork 
from MCTS import MCTS, MCTSNode
from tradinenvwithindicator import StockTradingEnvWithIndicators  # Adjusted to use the environment with indicators

from traincustomindicator import train_stock_custom_Indicator
from evaluatecustomindc import evaluate_with_indicators

from sklearn.preprocessing import StandardScaler
import pandas as pd
import torch
import os
import numpy as np

# %%
stock_file = "/home/vardaan/Thesis/Final stocks/AACG.csv"
agent, train_env, mcts = train_stock_custom_Indicator(
        stock_file=stock_file,
        year=2019,
        train_months=[2, 3],  # Training data months
        input_size=13,               # Number of features
        hidden_size=256,            # Hidden layer size in the model
        action_size=3,              # Number of possible actions (e.g., Buy, Sell, Hold)
        num_iterations=1000,
        batch_size=32,
        save_path="AACG_indic.pth"
)

evaluate_with_indicators(agent, stock_file, year=2019, mcts=mcts, test_months=[6], num_episodes=500, load_path="AACG_indic.pth")
# Out:
# /home/vardaan/Thesis/traincustomindicator.py:148: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.24574526 -0.69983975 -0.58917807 -0.3296955  -0.2915363   0.3915134
#   3.21529429  0.09387163 -1.08143176 -0.36022286  0.2007174   0.40296116
#  -0.16942685  0.66244373 -1.19972529]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.loc[:, ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']] = scaler.fit_transform(
# /home/vardaan/Thesis/traincustomindicator.py:64: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   states_tensor = torch.tensor(states, dtype=torch.float32)
# Iteration 1/1000, Loss: 61.3637, Profit: -15.5000, Reward: -14.0000
# ...

# %%
stock_file = "/home/vardaan/Thesis/Final stocks/A.csv"
agent, train_env, mcts = train_stock_custom_Indicator(
        stock_file=stock_file,
        year=2019,
        train_months=[2, 3],  # Training data months
        input_size=13,               # Number of features
        hidden_size=256,            # Hidden layer size in the model
        action_size=3,              # Number of possible actions (e.g., Buy, Sell, Hold)
        num_iterations=1000,
        batch_size=32,
        save_path="A_indic.pth"
)

evaluate_with_indicators(agent, stock_file, year=2019, mcts=mcts, test_months=[6], num_episodes=500, load_path="A_indic.pth")
# Out:
# /home/vardaan/Thesis/traincustomindicator.py:148: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.66396526  0.93391276 -0.22180301 -0.37875644 -0.10293647 -0.70966953
#  -1.2412917   0.57890749 -0.60639205 -0.17822452  0.35605488  2.21310091
#   0.63382347  3.2809511   1.91141729  0.28218402  0.48519601 -0.82251302
#   0.07155464 -0.16440694  2.63134814 -0.55466474  0.05631989  0.17607216
#  -0.41666618 -0.89957255 -0.33021779 -0.33588654 -0.79753511  0.49671066
#  -0.17893311 -0.96742037  0.08785229 -1.29691628 -0.50116594 -1.40958262
#  -0.51462921 -0.48291966 -0.18265322 -0.23668347]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.loc[:, ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']] = scaler.fit_transform(
# Iteration 1/1000, Loss: 594.6209, Profit: -42.0000, Reward: -38.0000
# ...

# %%
stock_file = "/home/vardaan/Thesis/Final stocks/AB.csv"
agent, train_env, mcts = train_stock_custom_Indicator(
        stock_file=stock_file,
        year=2019,
        train_months=[2, 3],  # Training data months
        input_size=13,               # Number of features
        hidden_size=256,            # Hidden layer size in the model
        action_size=3,              # Number of possible actions (e.g., Buy, Sell, Hold)
        num_iterations=1000,
        batch_size=32,
        save_path="AB_indic.pth"
)

evaluate_with_indicators(agent, stock_file, year=2019, mcts=mcts, test_months=[6], num_episodes=500, load_path="AB_indic.pth")
# Out:
# /home/vardaan/Thesis/traincustomindicator.py:148: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.01792153 -0.27349087  0.94017175  0.0259237  -0.46887721  0.04592913
#   0.70944248  0.73344899  1.66370138  4.01367229  0.93083588  1.94044313
#   0.41602954  0.83614352 -0.02809095 -0.43953592 -0.05609855 -0.74761951
#  -1.01369169 -0.07810452  0.2893285  -0.33750824 -0.76629124  0.62541968
#   0.22197689 -0.50422013 -1.02969604 -0.76695809 -1.02769549 -0.27215717
#  -0.87232    -0.9156651  -0.65292715 -0.4995522   1.33427867 -0.60958205
#  -0.73294886 -1.03436397 -0.75562168 -0.86165044]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.loc[:, ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']] = scaler.fit_transform(
# Iteration 1/1000, Loss: 259.9412, Profit: -22.0000, Reward: -18.0000
# ...
